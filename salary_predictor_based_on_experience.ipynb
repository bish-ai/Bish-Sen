# %% [markdown]
# <a href="https://colab.research.google.com/github/bish-ai/Bishal.py/blob/main/salary_predictor_based_on_experience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/80116/186341/Salary.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260201%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260201T073244Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
data.head()
data.isnull().sum()
data.drop_duplicates()
data.describe()
data.info()
data.corr()
data.shape
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
x=data.drop(columns=["Salary"])
y=data[["Salary"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)
x_train.head()
pd.DataFrame(x_train).skew()
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
pt_x_train=pt.fit_transform(x_train)
pt_x_test=pt.transform(x_test)
pt_x_train
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  35 non-null     float64
#  1   Salary           35 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 692.0 bytes
# array([[ 0.7058585 ],
#        [ 1.22054548],
#        [ 0.98100279],
#        [-0.55463825],
#        [-1.30013595],
#        [ 0.81379005],
#        [ 0.83504971],
#        [-0.01169325],
#        [ 1.59430417],
#        [-1.51595284],
#        [-0.84938951],
#        [-1.7055999 ],
#        [-0.61761002],
#        [ 0.45794891],
#        [ 0.19333481],
#        [-0.91929027],
#        [-0.68194858],
#        [-0.25769478],
#        [ 1.48519196],
#        [ 0.52708723],
#        [-1.60860516],
#        [ 0.26735011],
#        [-0.43247874],
#        [ 1.37357353]])

# %%
y_train.value_counts()
y_train.nunique()
y_train.sort_values(by=["Salary"])
from sklearn.preprocessing import StandardScaler
ss_target=StandardScaler()
ss_y_train=ss_target.fit_transform(y_train)
ss_y_test=ss_target.transform(y_test)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr_fit=lr.fit(pt_x_train,ss_y_train)
lr_pred_y_test=lr_fit.predict(ss_y_test)
lr_pred_y_test
from sklearn.metrics import r2_score
r2_score(ss_y_test,lr_pred_y_test)
# Out:
# 0.9996450094916136
