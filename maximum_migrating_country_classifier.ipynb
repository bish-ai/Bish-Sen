# %% [markdown]
# <a href="https://colab.research.google.com/github/bish-ai/Bishal.py/blob/main/maximum_migrating_country_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/9351247/14638568/country_millionaire_migration_2025.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260127%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260127T164302Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
data.head()
data.shape
data.isnull().sum()
data.drop_duplicates()
data.describe()
data.info()
data.tail()
x=data.drop(columns=["country"])#feauture columns#
y=data[["country"]]#target columns#
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,test_size=0.3)
x_train.head()
x_train.head()
from sklearn.preprocessing import StandardScaler
ss_input=StandardScaler()
ss_fit_transform_x_train=ss_input.fit_transform(x_train)
ss_transform_x_test=ss_input.transform(x_test)
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
ss_fit_transform_x_train_pt=pt.fit_transform(ss_fit_transform_x_train)
ss_transform_x_test_pt=pt.transform(ss_transform_x_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            10 non-null     object
#  1   net_millionaire_migration_2025     10 non-null     int64
#  2   estimated_migrating_wealth_usd_bn  10 non-null     float64
#  3   millionaire_growth_pct_2014_2024   10 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 452.0+ bytes

# %%
y_train.head()
y_train.shape
y_train.ndim
y_train.value_counts()
oe_target=OrdinalEncoder(handle_unknown="use_encoded_value",unknown_value=-1)
oe_fit_transform_y_train=oe_target.fit_transform(y_train)
oe_transform_y_test=oe_target.transform(y_test)
oe_transform_y_test
from sklearn.linear_model import LogisticRegression
lr_1=LogisticRegression()
lr_fit=lr_1.fit(ss_fit_transform_x_train_pt,y_train)
lr_fit.score(ss_fit_transform_x_train_pt,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5714285714285714
